# %%
import requests
import json
import gzip
import shutil
import time
import os
from io import BytesIO


S3_BUCKET_URL = "https://power-rankings-dataset-gprhack.s3.us-west-2.amazonaws.com"


def download_gzip_and_write_to_json(file_name):
   local_file_name = file_name.replace(":", "_")
   # If file already exists locally do not re-download game
   if os.path.isfile(f"{local_file_name}.json"):
       return

   response = requests.get(f"{S3_BUCKET_URL}/{file_name}.json.gz")
   if response.status_code == 200:
       try:
           gzip_bytes = BytesIO(response.content)
           with gzip.GzipFile(fileobj=gzip_bytes, mode="rb") as gzipped_file:
               with open(f"{local_file_name}.json", 'wb') as output_file:
                   shutil.copyfileobj(gzipped_file, output_file)
               print(f"{file_name}.json written")
       except Exception as e:
           print("Error:", e)
   else:
       print(f"Failed to download {file_name}")


def download_esports_files():
   directory = "esports-data"
   if not os.path.exists(directory):
       os.makedirs(directory)

   esports_data_files = ["leagues", "tournaments", "players", "teams", "mapping_data"]
   for file_name in esports_data_files:
       download_gzip_and_write_to_json(f"{directory}/{file_name}")


def download_games(year):
   start_time = time.time()
   with open("esports-data/tournaments.json", "r") as json_file:
       tournaments_data = json.load(json_file)
   with open("esports-data/mapping_data.json", "r") as json_file:
       mappings_data = json.load(json_file)

   directory = "games"
   if not os.path.exists(directory):
       os.makedirs(directory)

   mappings = {
       esports_game["esportsGameId"]: esports_game for esports_game in mappings_data
   }

   game_counter = 0
    
    
   # TEMPORARY
   MAX_GAMES = 50
   #################
   for tournament in tournaments_data:
       start_date = tournament.get("startDate", "")
       if start_date.startswith(str(year)):
           print(f"Processing {tournament['slug']}")
           for stage in tournament["stages"]:
               for section in stage["sections"]:
                   for match in section["matches"]:
                       for game in match["games"]:
                           ##############
                           if game_counter >= MAX_GAMES:
                               break
                           ##############
                           if game["state"] == "completed":
                               try:
                                   platform_game_id = mappings[game["id"]]["platformGameId"]
                               except KeyError:
                                   print(f"{platform_game_id} {game['id']} not found in the mapping table")
                                   continue

                               download_gzip_and_write_to_json(f"{directory}/{platform_game_id}")
                               game_counter += 1

                           if game_counter % 10 == 0:
                               print(
                                   f"----- Processed {game_counter} games, current run time: \
                                   {round((time.time() - start_time)/60, 2)} minutes"
                               )


if __name__ == "__main__":
   download_esports_files()
   download_games(2023)
# Out:
# esports-data/leagues.json written
# esports-data/tournaments.json written
# esports-data/players.json written
# esports-data/teams.json written
# esports-data/mapping_data.json written
# Processing nacl_qualifiers_2_summer_2023
# games/ESPORTSTMNT03:3196037.json written
# games/ESPORTSTMNT03:3196049.json written
# games/ESPORTSTMNT03:3196058.json written
# games/ESPORTSTMNT03:3197014.json written
# games/ESPORTSTMNT03:3198185.json written
# games/ESPORTSTMNT03:3200156.json written
# games/ESPORTSTMNT03:3199178.json written
# games/ESPORTSTMNT03:3198199.json written
# games/ESPORTSTMNT03:3200168.json written
# games/ESPORTSTMNT03:3198544.json written
# ----- Processed 10 games, current run time:                                    0.23 minutes
# games/ESPORTSTMNT03:3198546.json written
# games/ESPORTSTMNT03:3195064.json written
# games/ESPORTSTMNT03:3196051.json written
# games/ESPORTSTMNT03:3196057.json written
# ESPORTSTMNT03:3196057 110733838936446954 not found in the mapping table
# games/ESPORTSTMNT03:3197025.json written
# games/ESPORTSTMNT03:3198183.json written
# games/ESPORTSTMNT03:3199172.json written
# games/ESPORTSTMNT03:3198196.json written
# games/ESPORTSTMNT03:3200165.json written
# games/ESPORTSTMNT03:3198206.json written
# ----- Processed 20 games, current run time:                                    0.42 minutes
# games/ESPORTSTMNT03:3198553.json written
# games/ESPORTSTMNT03:3199526.json written
# games/ESPORTSTMNT03:3199528.json written
# games/ESPORTSTMNT03:3195262.json written
# games/ESPORTSTMNT03:3197195.json written
# games/ESPORTSTMNT03:3197205.json written
# games/ESPORTSTMNT03:3195300.json written
# games/ESPORTSTMNT03:3198294.json written
# games/ESPORTSTMNT03:3199274.json written
# games/ESPORTSTMNT03:3198298.json written
# ----- Processed 30 games, current run time:                                    0.58 minutes
# games/ESPORTSTMNT03:3198299.json written
# games/ESPORTSTMNT03:3200543.json written
# games/ESPORTSTMNT03:3199525.json written
# games/ESPORTSTMNT03:3197182.json written
# games/ESPORTSTMNT03:3195276.json written
# games/ESPORTSTMNT03:3195306.json written
# games/ESPORTSTMNT03:3196275.json written
# games/ESPORTSTMNT03:3198292.json written
# games/ESPORTSTMNT03:3198296.json written
# ESPORTSTMNT03:3198296 110733838936447001 not found in the mapping table
# ESPORTSTMNT03:3198296 110733838936447002 not found in the mapping table
# games/ESPORTSTMNT03:3200536.json written
# ----- Processed 40 games, current run time:                                    0.77 minutes
# games/ESPORTSTMNT03:3200539.json written
# games/ESPORTSTMNT03:3199520.json written
# games/ESPORTSTMNT03:3198611.json written
# games/ESPORTSTMNT03:3200605.json written
# games/ESPORTSTMNT03:3198621.json written
# games/ESPORTSTMNT03:3200613.json written
# games/ESPORTSTMNT03:3200614.json written
# games/ESPORTSTMNT03:3198612.json written
# games/ESPORTSTMNT03:3200607.json written
# games/ESPORTSTMNT03:3200609.json written
# ----- Processed 50 games, current run time:                                    0.92 minutes
# Processing gll_summer_2023
# Processing elite_series_summer_2023
# Processing superliga_summer_2023
# Processing ultraliga_summer_2023
# Processing lpl_regional_finals_2023
# Processing tcl_summer_2023
# Processing nlc_summer_2023
# Processing ljl_academy_2023
# Processing pg_nationals_summer_2023
# Processing ebl_summer_2023
# Processing lrs_closing_2023
# Processing liga_portuguesa_summer_2023
# Processing lck_challengers_spring_2023
# Processing lpl_summer_2023
# Processing vcs_summer_2023
# Processing vcs_spring_2023
# Processing ddh_opening_2023
# Processing elite_series_spring_2023
# Processing cblol_academy_2023_split_2
# Processing golden_league_opening_2023
# Processing nlc_spring_2023
# Processing lla_closing_2023
# Processing emea_masters_spring_main_2023
# Processing superliga_spring_2023
# Processing pcs_spring_2023
# Processing lfl_spring_2023
# Processing nacl_summer_2023
# Processing nacl_qualifiers_1_summer_2023
# Processing lfl_summer_2023
# Processing hitpoint_masters_spring_2023
# Processing prime_league_summer_2023
# Processing lec_spring_2023
# Processing stars_league_opening_2023
# Processing ljl_spring_2023
# Processing el_opening_2023
# Processing ebl_spring_2023
# Processing ultraliga_spring_2023
# Processing honor_league_opening_2023
# Processing nacl_qualifiers_1_spring_2023
# Processing tcl_spring_2023
# Processing emea_masters_summer_2023
# Processing pcs_summer_playoffs_2023
# Processing cblol_2023_split_2
# Processing lco_split_2_2023
# Processing lcs_summer_2023
# Processing lec_summer_2023
# Processing msi_2023
# Processing ljl_summer_2023
# Processing lco_split_1_2023
# Processing lck_spring_2023
# Processing arabian_league_summer_2023
# Processing lck_challengers_summer_2023
# Processing lck_summer_2023
# Processing emea_masters_spring_play_ins_2023
# Processing liga_portuguesa_spring_2023
# Processing lrn_closing_2023
# Processing nacl_promotion_spring_2023
# Processing lec_season_finals_2023
# Processing pcs_summer_2023
# Processing hitpoint_masters_summer_2023
# Processing cblol_academy_2023_split_1
# Processing nacl_spring_2023
# Processing liga_master_opening_2023
# Processing lec_winter_2023
# Processing nacl_qualifiers_2_spring_2023
# Processing lcs_spring_2023
# Processing vdl_opening_2023
# Processing prime_league_spring_2023
# Processing gll_spring_2023
# Processing pcs_spring_playoffs_2023
# Processing lla_opening_2023
# Processing pg_nationals_spring_2023
# Processing cblol_2023_split_1
# Processing arabian_league_spring_2023

# %%
import requests
import json
import gzip
import shutil
import time
import os
from io import BytesIO


S3_BUCKET_URL = "https://power-rankings-dataset-gprhack.s3.us-west-2.amazonaws.com"


def download_gzip_and_write_to_json(file_name):
   local_file_name = file_name.replace(":", "_")
   # If file already exists locally do not re-download game
   if os.path.isfile(f"{local_file_name}.json"):
       return

   response = requests.get(f"{S3_BUCKET_URL}/{file_name}.json.gz")
   if response.status_code == 200:
       try:
           gzip_bytes = BytesIO(response.content)
           with gzip.GzipFile(fileobj=gzip_bytes, mode="rb") as gzipped_file:
               with open(f"{local_file_name}.json", 'wb') as output_file:
                   shutil.copyfileobj(gzipped_file, output_file)
               print(f"{file_name}.json written")
       except Exception as e:
           print("Error:", e)
   else:
       print(f"Failed to download {file_name}")


def download_esports_files():
   directory = "esports-data"
   if not os.path.exists(directory):
       os.makedirs(directory)

   esports_data_files = ["leagues", "tournaments", "players", "teams", "mapping_data"]
   for file_name in esports_data_files:
       download_gzip_and_write_to_json(f"{directory}/{file_name}")


def download_games(year):
   start_time = time.time()
   with open("esports-data/tournaments.json", "r") as json_file:
       tournaments_data = json.load(json_file)
   with open("esports-data/mapping_data.json", "r") as json_file:
       mappings_data = json.load(json_file)

   directory = "games"
   if not os.path.exists(directory):
       os.makedirs(directory)

   mappings = {
       esports_game["esportsGameId"]: esports_game for esports_game in mappings_data
   }

   game_counter = 0
    
    
   # TEMPORARY
   MAX_GAMES = 50
   #################
   for tournament in tournaments_data:
       start_date = tournament.get("startDate", "")
       if start_date.startswith(str(year)):
           print(f"Processing {tournament['slug']}")
           for stage in tournament["stages"]:
               for section in stage["sections"]:
                   for match in section["matches"]:
                       for game in match["games"]:
                           ##############
                           if game_counter >= MAX_GAMES:
                               break
                           ##############
                           if game["state"] == "completed":
                               try:
                                   platform_game_id = mappings[game["id"]]["platformGameId"]
                               except KeyError:
                                   print(f"{platform_game_id} {game['id']} not found in the mapping table")
                                   continue

                               download_gzip_and_write_to_json(f"{directory}/{platform_game_id}")
                               game_counter += 1

                           if game_counter % 10 == 0:
                               print(
                                   f"----- Processed {game_counter} games, current run time: \
                                   {round((time.time() - start_time)/60, 2)} minutes"
                               )


if __name__ == "__main__":
   download_esports_files()
   download_games(2022)
# Out:
# Processing elements_league_opening_2022
# games/ESPORTSTMNT01:2706724.json written
# games/ESPORTSTMNT03:2543653.json written
# games/ESPORTSTMNT02:2577618.json written
# games/ESPORTSTMNT02:2553984.json written
# games/ESPORTSTMNT02:2557132.json written
# games/ESPORTSTMNT01:2697304.json written
# games/ESPORTSTMNT02:2573380.json written
# games/ESPORTSTMNT02:2553970.json written
# games/ESPORTSTMNT03:2543686.json written
# games/ESPORTSTMNT02:2557639.json written
# ----- Processed 10 games, current run time:                                    0.24 minutes
# games/ESPORTSTMNT02:2573377.json written
# games/ESPORTSTMNT02:2557126.json written
# games/ESPORTSTMNT01:2697336.json written
# games/ESPORTSTMNT02:2573359.json written
# games/ESPORTSTMNT01:2697284.json written
# games/ESPORTSTMNT02:2557653.json written
# games/ESPORTSTMNT01:2706774.json written
# games/ESPORTSTMNT02:2557118.json written
# games/ESPORTSTMNT02:2557107.json written
# games/ESPORTSTMNT01:2697328.json written
# ----- Processed 20 games, current run time:                                    0.42 minutes
# games/ESPORTSTMNT02:2553948.json written
# games/ESPORTSTMNT01:2706746.json written
# games/ESPORTSTMNT01:2706768.json written
# games/ESPORTSTMNT02:2573386.json written
# games/ESPORTSTMNT03:2543672.json written
# games/ESPORTSTMNT03:2543629.json written
# games/ESPORTSTMNT02:2553919.json written
# games/ESPORTSTMNT02:2557618.json written
# games/ESPORTSTMNT03:2544489.json written
# games/ESPORTSTMNT01:2772484.json written
# ----- Processed 30 games, current run time:                                    0.59 minutes
# games/ESPORTSTMNT01:2781985.json written
# games/ESPORTSTMNT01:2743216.json written
# games/ESPORTSTMNT01:2743930.json written
# games/ESPORTSTMNT03:2548593.json written
# games/ESPORTSTMNT03:2568649.json written
# games/ESPORTSTMNT01:2743231.json written
# games/ESPORTSTMNT01:2772462.json written
# games/ESPORTSTMNT01:2781996.json written
# games/ESPORTSTMNT03:2568656.json written
# games/ESPORTSTMNT01:2743968.json written
# ----- Processed 40 games, current run time:                                    0.78 minutes
# games/ESPORTSTMNT03:2548560.json written
# games/ESPORTSTMNT03:2568670.json written
# games/ESPORTSTMNT03:2548617.json written
# games/ESPORTSTMNT01:2781971.json written
# games/ESPORTSTMNT03:2544411.json written
# games/ESPORTSTMNT01:2744022.json written
# games/ESPORTSTMNT01:2744040.json written
# games/ESPORTSTMNT03:2548583.json written
# games/ESPORTSTMNT01:2743259.json written
# games/ESPORTSTMNT03:2544466.json written
# ----- Processed 50 games, current run time:                                    0.95 minutes
# Processing lck_challengers_spring_2022
# Processing cblol_academy_split_1_2022
# Processing lcs_proving_grounds_summer_2022
# Processing pcs_spring_2022
# Processing lck_summer_2022
# Processing prime_league_summer_2022
# Processing hitpoint_masters_summer_2022
# Processing superliga_spring_2022
# Processing lco_split_2_2022
# Processing honor_division_closing_2022
# Processing lck_academy_01_2022
# Processing lck_challengers_summer_2022
# Processing lec_spring_2022
# Processing lcs_academy_summer_2022
# Processing cblol_academy_split_2_2022
# Processing stars_league_opening_2022
# Processing ultraliga_spring_2022
# Processing msi_2022
# Processing lcs_summer_2022
# Processing ultraliga_summer_2022
# Processing lcs_lock_in_2022
# Processing pcs_summer_2022
# Processing elements_league_closing_2022
# Processing ljl_summer_2022
# Processing worlds_2022
# Processing lck_regional_finals_2022
# Processing superliga_summer_2022
# Processing greek_legends_league_spring_2022
# Processing tal_summer_2022
# Processing pg_nationals_spring_2022
# Processing greek_legends_league_summer_2022
# Processing volcano_league_opening_2022
# Processing esports_balkan_league_spring_2022
# Processing european_masters_summer_2022_play_ins
# Processing golden_league_super_finals_2022
# Processing lla_promotion_2022
# Processing stars_league_super_finals_2022
# Processing volcano_league_super_finals_2022
# Processing lec_summer_2022
# Processing tcl_winter_2022
# Processing lcs_proving_grounds_spring_2022
# Processing cblol_split_1_2022
# Processing lcs_amateur_circuit_summer_2022
# Processing liga_portuguesa_summer_2022
# Processing lcl_spring_2022
# Processing ljl_academy_2022
# Processing elite_series_spring_2022
# Processing lco_split_1_2022
# Processing tcl_summer_2022
# Processing european_masters_spring_2022_main_event
# Processing nlc_spring_2022
# Processing stars_league_closing_2022
# Processing honor_league_opening_2022
# Processing honor_division_opening_2022
# Processing honor_league_closing_2022
# Processing lfl_2022_spring
# Processing lcs_academy_spring_2022
# Processing lck_spring_2022
# Processing lfl_2022_summer
# Processing volcano_league_closing_2022
# Processing tal_winter_2022
# Processing elite_series_summer_2022
# Processing cblol_split_2_2022
# Processing lla_opening_2022
# Processing prime_league_spring_2022
# Processing liga_portuguesa_spring_2022
# Processing european_masters_summer_2022_main_event
# Processing golden_league_closing_2022
# Processing master_flow_league_opening_2022
# Processing lcs_spring_2022
# Processing lla_closing_2022
# Processing master_flow_league_closing_2022
# Processing nlc_summer_2022
# Processing esports_balkan_league_summer_2022
# Processing european_masters_spring_2022_play_ins
# Processing hitpoint_masters_spring_2022
# Processing ljl_spring_2022
# Processing golden_league_opening_2022
# Processing pg_nationals_summer_2022
# Processing lcs_amateur_circuit_summer_2022
# Processing college_championship_2022
